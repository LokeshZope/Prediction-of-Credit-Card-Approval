# %% [markdown]
# ## Introduction

# %% [markdown]
#    Credit cards are a widely utilised financial instrument. However, because of a number of variables, including employment position and income level, getting a credit card can be challenging for many people. Credit card approval can be predicted by machine learning models, which can assist  the application process and increase the approval rate.
#    The goal of the project is to  investigate the relationship between several parameters and credit card acceptance rates and  apply predictive models to increase the precision of credit card approval forecasts.

# %% [markdown]
# ## Attributes Description

# %% [markdown]
# Ind_id: This column indicates the indivisual id.
#
# GENDER: This column indicates the gender of the individual, either male or female.
#         Type: Categorical (binary).
#
# Car_Owner: This column indicates whether the individual owns a car or not, either Yes or No.
#         Type: Categorical (binary).
#
# Propert_Owner: This column indicates whether the individual owns a property or not, either Yes or No.
#         Type: Categorical (binary).
#
# CHILDREN: This column indicates the number of children the individual has.
#         Type: Numerical(integer).
#
# Annual_income: This column contains the annual income of the individual.
#         Type: Numerical (continuous).
#
# Type_Income: This column indicates the type of income the individual earns, such as salary or self-employed income.
#         Type: Numerical (nominal).
#
# EDUCATION: This column indicates the level of education of the individual.
#         Type: Categorical (ordinal).
#
# Marital_status: This column indicates the marital status of the individual, such as Single, Married, Divorced, etc.
#         Type: Categorical (nominal).
#
# Housing_type: This column indicates the type of housing the individual lives in, such as a house or apartment.
#         Type: Categorical (nominal).
#
# Birthday_count: This column contains the age of the individual.
#         Type: Numerical(integer).
#
# Employed_days: This column indicates the number of days the individual has been employed.
#         Type: Numerical(integer).
#
# Mobile_phone, Work_Phone, Phone: These columns indicates the contact information of individual.
#         Type: Categorical (binary)
#
# EMAIL_ID:These column indicates whether individual has email_id or not
#         Type: Categorical (nominal).
#
# Type_Occupation: This column indicates the type of occupation of the individual, such as healthcare or education.
#         Type: Categorical (nominal).
#
# Family_Members: This column indicates the number of family members the individual has.
#         Type: Numeric (integer).
#
# Label: This column contains the label for credit card approval, either approved or not approved.
#         Type: Categorical (binary)

# %% [markdown]
# ### 1) Why is your proposal important in today’s world? How predicting a good client is worthy for a bank?

# %% [markdown]
# The growing popularity of credit cards as a financial instrument makes the idea of predicting credit card approval extremely useful in the modern world. Since credit cards are now used by many people as their principal mode of payment for online and e-commerce transactions, banks must process credit card applications quickly and increase the approval rate. For a bank, predicting a good customer is crucial since it lowers the danger of credit default and lowers the expense of credit card account management. Machine learning algorithms are a useful tool for banks to analyse a variety of data, including employment status and income level. Reliability allows banks to provide credit cards to customers with reduced risk profiles, which can ultimately result in improved profitability.

# %% [markdown]
# ### 2) How is it going to impact the banking sector?

# %% [markdown]
# Machine learning-based credit card approval prediction has the potential to completely change the banking industry by enhancing consumer satisfaction, lowering risk, and boosting earnings.
#
# Better customer experience: Banks can provide quicker and more accurate credit card approvals by utilising predictive algorithms, which can enhance the general consumer experience. Increased client happiness and loyalty may result from this.
#
# Decreased risk of credit defaults: Banks can more precisely anticipate a customer's tendency to miss credit card payments with the use of machine learning algorithms. Banks can provide credit cards with reduced interest rates to customers who fit their lower credit risk profiles. This lowers the danger of default and eventually boosts the bank's profitability.

# %% [markdown]
# ### 3)If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India.

# %% [markdown]
# The suggested approach can help Indian banks fill any knowledge or process gaps regarding credit card approval by increasing the efficiency, strengthening credit risk management tactics, and predicting credit card approval more accurately. But banks will need to make sure they have access to trustworthy and complete data sources if they want to take full advantage of our suggested approach.

# %%
# Importing necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
#loading the datasets
data1 = pd.read_csv('Credit_card.csv')
data2 = pd.read_csv('Credit_card_label.csv')

#Merging the datasets
data = pd.merge(data1,data2, on = 'Ind_ID')

# %% [markdown]
# ## Data Exploration (Exploratory Data Analysis or EDA)

# %%
# Let's check the top 5 rows of our dataframe
data.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %%
# Let's check the bottom 5 rows of our dataframe
data.tail()
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 1543  Commercial associate               Higher education
# 1544  Commercial associate              Incomplete higher
# 1545               Working               Higher education
# 1546               Working  Secondary / secondary special
# 1547               Working               Higher education
#
#             Marital_status       Housing_type  Birthday_count  Employed_days  \
# 1543               Married  House / apartment        -11957.0          -2182
# ...

# %%
#Finding the mean, min, max, and std deviation
data.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# ...

# %%
data.shape
# Out:
# (1548, 19)

# %%
# find out how many null values are present
data.isnull().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
## Display number of rows, columns and their data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
# Exploring the missing values
import missingno as msno
msno.bar(data)
# Out:
# <Axes: >

# %%
# Visualisation of missing values
fig, ax = plt.subplots(figsize=(12, 6))
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# Imputing the null values with mean values
data.fillna(data.mean(), inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15832\1214182270.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)

# %%
# Finding null values
data.isnull().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income        0
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count       0
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
#Replace missing values
data['Type_Occupation'].fillna('Other', inplace = True)

# %%
# Deleting the null values in gender column
data = data.dropna(subset=['GENDER'])

# %%
#Checking the missing values
data.isnull().sum()
# Out:
# Ind_ID             0
# GENDER             0
# Car_Owner          0
# Propert_Owner      0
# CHILDREN           0
# Annual_income      0
# Type_Income        0
# EDUCATION          0
# Marital_status     0
# Housing_type       0
# Birthday_count     0
# Employed_days      0
# Mobile_phone       0
# Work_Phone         0
# Phone              0
# EMAIL_ID           0
# Type_Occupation    0
# Family_Members     0
# label              0
# dtype: int64

# %%
# Converting all the negative values to actual age value
data['Birthday_count']  = abs(round((data['Birthday_count']/-365),0))

#Converting the negative values to actual experience of the employee
data['Employed_days']=abs(round((data['Employed_days']/-365),0))

# %%
data
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0   180000.00000
# 1     5009744      F         Y             N         0   315000.00000
# 2     5009746      F         Y             N         0   315000.00000
# 3     5009749      F         Y             N         0   191399.32623
# 4     5009752      F         Y             N         0   315000.00000
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0   191399.32623
# 1544  5023655      F         N             N         0   225000.00000
# 1545  5115992      M         Y             Y         2   180000.00000
# 1546  5118219      M         Y             N         0   270000.00000
# 1547  5053790      F         Y             Y         0   225000.00000
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
# Checking for outliers
data.describe(percentiles = [0.05, 0.10, 0.25, 0.50, 0.75, 0.80, 0.85, 0.90, 0.95, 0.99])
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.541000e+03  1541.000000   1.541000e+03     1541.000000
# mean   5.078979e+06     0.413368   1.908057e+05       43.974692
# std    4.167137e+04     0.777811   1.121136e+05       11.517294
# min    5.008827e+06     0.000000   3.375000e+04       21.000000
# 5%     5.018505e+06     0.000000   7.650000e+04       27.000000
# 10%    5.023655e+06     0.000000   9.000000e+04       29.000000
# 25%    5.045113e+06     0.000000   1.215000e+05       34.000000
# 50%    5.078924e+06     0.000000   1.710000e+05       43.000000
# 75%    5.115671e+06     1.000000   2.250000e+05       53.000000
# 80%    5.118026e+06     1.000000   2.475000e+05       56.000000
# 85%    5.126518e+06     1.000000   2.700000e+05       58.000000
# 90%    5.140019e+06     1.000000   3.150000e+05       60.000000
# 95%    5.145964e+06     2.000000   3.600000e+05       64.000000
# 99%    5.149625e+06     3.000000   5.670000e+05       67.000000
# ...

# %%
from scipy import stats

# %%
z = stats.zscore(data['Employed_days'])

# %%
z
# Out:
# 0       2.219379
# 1      -0.464722
# 2      -0.464722
# 3      -0.464722
# 4      -0.464722
#           ...
# 1543   -0.453975
# 1544   -0.462035
# 1545   -0.451288
# 1546   -0.464722
# 1547   -0.448601
# Name: Employed_days, Length: 1541, dtype: float64

# %%
threshold = 3
b = np.where(z>3)
print(np.where(z>3))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(z<-3))
# Out:
# (array([], dtype=int64),)

# %%
# replacing the extreme values with zero.
data['Employed_days'].replace(1001.0, 0,inplace=True)

# %%
data.head()
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0   180000.00000
# 1  5009744      F         Y             N         0   315000.00000
# 2  5009746      F         Y             N         0   315000.00000
# 3  5009749      F         Y             N         0   191399.32623
# 4  5009752      F         Y             N         0   315000.00000
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %% [markdown]
# ## Data Visualization

# %%
# count number of males and females 
gender_count=data['GENDER'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(4,4))
plt.bar(gender_count.index,gender_count.values, color=["olive", "darkviolet"], width = 0.4, edgecolor='black')
plt.xlabel('GENDER')
plt.ylabel('Count')
plt.title('Distribution of Gender')
plt.show()

# %%
# count number of car owner
car_owner_count=data['Car_Owner'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(4,4))
plt.bar(car_owner_count.index,car_owner_count.values, color=["olive", "darkviolet"], width = 0.4, edgecolor='black' )
plt.xlabel('car_owner_count')
plt.ylabel('Count')
plt.title('Distribution of car_owner')
plt.show()

# %%
# count number of propert_owner
propert_owner_count=data['Propert_Owner'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(4,4))
plt.bar(propert_owner_count.index,propert_owner_count.values,  color=["olive", "darkviolet"], width = 0.4, edgecolor='black')
plt.xlabel('propert_owner_count')
plt.ylabel('Count')
plt.title('Distribution of propert_owner')
plt.show()

# %%
# count number of children
children_count=data['CHILDREN'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(5,4))
plt.bar(children_count.index,children_count.values, color=["magenta"], edgecolor='black')
plt.xlabel('children_count')
plt.ylabel('count')
plt.title('Distribution of children_count')
plt.show()

# %%
# histograph on Annual_income
plt.figure(figsize=(5,4))
plt.hist(data['Annual_income'], bins=10 , color = ["olivedrab"], edgecolor='black')
plt.xlabel('Annual_income')
plt.ylabel('count')
plt.title('Distribution of Annual_income')
plt.show()

# %%
# count number of Type_Income
Type_Income_count=data['Type_Income'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Type_Income_count.index,Type_Income_count.values, color=["magenta"], width = 0.5, edgecolor='black')
plt.xlabel('Type_Income')
plt.ylabel('count')
plt.title('Distribution of Type_Income')
plt.show()

# %%
Education_count=data['EDUCATION'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Education_count.index,Education_count.values, color=["magenta"], edgecolor='black')
plt.xlabel('Education')
plt.ylabel('count')
plt.title('Distribution of Education')
plt.show()

# %%
# count number of Marital_status
Marital_status_count=data['Marital_status'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Marital_status_count.index,Marital_status_count.values, color=["magenta"], edgecolor='black')
plt.xlabel('Marital_status')
plt.ylabel('count')
plt.title('Distribution of Marital_status')
plt.show()

# %%
# count number of Housing_type
Housing_type_count=data['Housing_type'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Housing_type_count.index,Housing_type_count.values, color=["magenta"], edgecolor='black')
plt.xlabel('Housing_type')
plt.ylabel('count')
plt.title('Distribution of Housing_type')
plt.show()

# %%
# count number of Birthday_count
Birthday_count=data['Birthday_count'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Birthday_count.index,Birthday_count.values, color=["magenta"], edgecolor='black')
plt.xlabel('Age')
plt.ylabel('count')
plt.title('Distribution of Age')
plt.show()

# %%
Employed_days_count=data['Employed_days'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Employed_days_count.index,Employed_days_count.values, color=["magenta"], edgecolor='black')
plt.xlabel('Employed_exp')
plt.ylabel('count')
plt.title('Distribution of Employed_exp')
plt.show()

# %%
# count number of Type_Occupation
Type_Occupation_count=data['Type_Occupation'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(30,10))
plt.bar(Type_Occupation_count.index,Type_Occupation_count.values, color =["magenta"], edgecolor='black')
plt.xlabel('Type_Occupation')
plt.ylabel('count')
plt.title('Distribution of Type_Occupation')
plt.show()

# %%
# count number of Family_Members
Family_Members_count=data['Family_Members'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Family_Members_count.index,Family_Members_count.values, color =["magenta"], edgecolor='black')
plt.xlabel('Family_Members')
plt.ylabel('count')
plt.title('Distribution of Family_Members')
plt.show()

# %%
# count number of label
label_count=data['label'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(4,4))
plt.bar(label_count.index,label_count.values,  color=["olive", "darkviolet"], width = 0.4, edgecolor='black')
plt.xlabel('label')
plt.ylabel('count')
plt.title('Distribution of label')
plt.locator_params(axis='x',nbins=2)
plt.show()

# %%
#Saving the data
data.to_csv("Capstone_Project-1.csv")

# %%
# Checking the correlation between different columns
corr_matrix = data.corr()
corr_matrix
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15832\184011309.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
#                   Ind_ID  CHILDREN  Annual_income  Birthday_count  \
# Ind_ID          1.000000  0.031011       0.031124       -0.024104
# CHILDREN        0.031011  1.000000       0.077523       -0.277323
# Annual_income   0.031124  0.077523       1.000000       -0.107153
# Birthday_count -0.024104 -0.277323      -0.107153        1.000000
# Employed_days   0.011011  0.072874       0.051592       -0.022359
# Mobile_phone         NaN       NaN            NaN             NaN
# Work_Phone      0.088162  0.035572      -0.070056       -0.172915
# Phone           0.010014 -0.006054      -0.011358        0.032348
# EMAIL_ID       -0.042415  0.023954       0.119364       -0.164741
# ...

# %%
# Plotting heatmap for correlation
corr_matrix = data.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, 
            annot=True, 
            linewidths=0.5, 
            fmt= ".2f", 
            cmap="YlGnBu");
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15832\1150120860.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %%
# removing unused columns
data = data.drop(['Ind_ID', 'Mobile_phone','Work_Phone','Phone','EMAIL_ID'], axis=1)

# %%
data.head()
# Out:
#   GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0      M         Y             Y         0   180000.00000
# 1      F         Y             N         0   315000.00000
# 2      F         Y             N         0   315000.00000
# 3      F         Y             N         0   191399.32623
# 4      F         Y             N         0   315000.00000
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days Type_Occupation  Family_Members  label
# 0            51.0            0.0           Other               2      1
# ...

# %% [markdown]
# ## Feature Engineering

# %%
# converting non numeric data to numeric 
#Importing Label Encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in data:
    if data[col].dtype=='object':
        data[col]=le.fit_transform(data[col])

# %%
data.head()
# Out:
#    GENDER  Car_Owner  Propert_Owner  CHILDREN  Annual_income  Type_Income  \
# 0       1          1              1         0   180000.00000            1
# 1       0          1              0         0   315000.00000            0
# 2       0          1              0         0   315000.00000            0
# 3       0          1              0         0   191399.32623            0
# 4       0          1              0         0   315000.00000            0
#
#    EDUCATION  Marital_status  Housing_type  Birthday_count  Employed_days  \
# 0          1               1             1            51.0            0.0
# 1          1               1             1            37.0            2.0
# 2          1               1             1            44.0            2.0
# 3          1               1             1            37.0            2.0
# 4          1               1             1            37.0            2.0
#
#    Type_Occupation  Family_Members  label
# ...

# %%
data.tail()
# Out:
#       GENDER  Car_Owner  Propert_Owner  CHILDREN  Annual_income  Type_Income  \
# 1543       0          0              1         0   191399.32623            0
# 1544       0          0              0         0   225000.00000            0
# 1545       1          1              1         2   180000.00000            3
# 1546       1          1              0         0   270000.00000            3
# 1547       0          1              1         0   225000.00000            3
#
#       EDUCATION  Marital_status  Housing_type  Birthday_count  Employed_days  \
# 1543          1               1             1            33.0            6.0
# 1544          2               3             1            28.0            3.0
# 1545          1               1             1            36.0            7.0
# 1546          4               0             1            42.0            2.0
# 1547          1               1             1            45.0            8.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1541 entries, 0 to 1547
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GENDER           1541 non-null   int32
#  1   Car_Owner        1541 non-null   int32
#  2   Propert_Owner    1541 non-null   int32
#  3   CHILDREN         1541 non-null   int64
#  4   Annual_income    1541 non-null   float64
#  5   Type_Income      1541 non-null   int32
#  6   EDUCATION        1541 non-null   int32
#  7   Marital_status   1541 non-null   int32
#  8   Housing_type     1541 non-null   int32
#  9   Birthday_count   1541 non-null   float64
#  10  Employed_days    1541 non-null   float64
#  11  Type_Occupation  1541 non-null   int32
#  12  Family_Members   1541 non-null   int64
#  13  label            1541 non-null   int64
# dtypes: float64(3), int32(8), int64(3)
# memory usage: 164.7 KB

# %% [markdown]
# ## Splitting the data (Test_Train split)

# %%
X = data.drop(columns = 'label')
Y = data['label']

# %%
#splitting data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
# count the number rows and columns for x_test
X_test.shape
# Out:
# (463, 13)

# %%
# count the number rows and columns for x_train
X_train.shape
# Out:
# (1078, 13)

# %%
# count the number rows for y_test
Y_test.shape
# Out:
# (463,)

# %%
# count the number rows for y_train
Y_train.shape
# Out:
# (1078,)

# %% [markdown]
# ## Scaling

# %%
# importing the MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(X_train)
x_test = scaler.fit_transform(X_test)
print(x_train.shape)
print(x_test.shape)
# Out:
# (1078, 13)
# (463, 13)

# %% [markdown]
# ## Logistic Regression Classifier

# %%
# importing the LogisticRegression
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression()
log_reg.fit(x_train, Y_train)
# Out:
# LogisticRegression()

# %%
#Importing scikit-learn metrics module for accuracy calculation
from sklearn import metrics
from sklearn.metrics import accuracy_score
y_pred = log_reg.predict(x_test)
print("logistic regression training set:",log_reg.score(X_train, Y_train))
print("logistic regression testing set:",log_reg.score(X_test, Y_test))
print("Accuracy of logistic regression classifier: ", accuracy_score(Y_test,y_pred))
# Out:
# logistic regression training set: 0.10296846011131726
# logistic regression testing set: 0.12742980561555076
# Accuracy of logistic regression classifier:  0.8725701943844493
# D:\Anaconda\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model = LogisticRegression()
ssplit =ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,Y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.88996764 0.86731392 0.8802589  0.8802589  0.8802589  0.8802589
#  0.89320388 0.89967638 0.89644013 0.88673139]
# 0.8854368932038836

# %% [markdown]
# ## Decision tree classifier

# %%
# decision tree classification 
from sklearn.tree import DecisionTreeClassifier
dec_tree = DecisionTreeClassifier()
dec_tree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dec_tree.predict(x_test)
print("decision tree training set:",dec_tree.score(X_train, Y_train))
print("decision tree testing set:",dec_tree.score(X_test, Y_test))
print("Accuracy of decision tree classifier :", accuracy_score(Y_test,y_pred))
# Out:
# decision tree training set: 0.9972170686456401
# decision tree testing set: 0.8315334773218143
# Accuracy of decision tree classifier : 0.8725701943844493
# D:\Anaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model= DecisionTreeClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,Y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.8802589  0.87055016 0.88673139 0.85113269 0.83171521 0.87055016
#  0.84142395 0.87702265 0.90291262 0.84142395]
# 0.8653721682847897

# %% [markdown]
# ## Random Forest Classifier

# %%
#Random Forest Classification
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)
print("rf training set:",rf.score(X_train, Y_train))
print("rf testing set:",rf.score(X_test, Y_test))
print("Random Forest classifier has accuracy of: ", accuracy_score(Y_test, y_pred))
# Out:
# rf training set: 0.9972170686456401
# rf testing set: 0.9092872570194385
# Random Forest classifier has accuracy of:  0.9092872570194385

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model=RandomForestClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,Y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.96116505 0.90291262 0.92880259 0.91909385 0.92556634 0.91262136
#  0.92880259 0.92556634 0.89320388 0.92880259]
# 0.9226537216828479

# %% [markdown]
# ## KNN Classifier

# %%
# KNN Classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)
print("knn training set:",knn.score(X_train, Y_train))
print("knn testing set:",knn.score(X_test, Y_test))
print("KNN classifier has accuracy of: ", accuracy_score(Y_test, y_pred))
# Out:
# knn training set: 0.9035250463821892
# knn testing set: 0.8617710583153347
# KNN classifier has accuracy of:  0.8617710583153347

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model = KNeighborsClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,Y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.85113269 0.86731392 0.86084142 0.87378641 0.87055016 0.84789644
#  0.8802589  0.86084142 0.86731392 0.89320388]
# 0.8673139158576053

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Hence we got accuracy on different classification
#
# -Logisitic regression got accuracy 88.54%
#
# -DecisionTree got accuracy 86.53%
#
# -Random Forest got accuracy 92.26%
#
# -KNN got accuracy 86.73%

# %% [markdown]
# After feature selection we used four machine learning models and achieved quite good accuracy of 92.26% in Random Forest for predicting the credit card approval.
